# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("housing.csv")

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
X=df.iloc[:,0:13]
X
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %%
y=df['medv']
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
print(X_train.shape)
# Out:
# (354, 13)

# %%
from sklearn.linear_model import LinearRegression
le=LinearRegression()
le.fit(X_train,y_train)
predictions=le.predict(X_test)
predictions
# Out:
# array([17.96814548, 12.78428442,  6.94011328, 24.75781118, 15.35544854,
#        19.10708679, 11.12362186, 41.77478219, 25.03323522, 22.41615383,
#        23.43366136, 34.02279367, 24.29847992, 13.29531062, 32.84998652,
#        40.71174046, 30.08851849, 27.27732581, 37.38152674, 12.23988394,
#        10.39465466, 16.25530462, 12.78015186, 26.91162414, 24.04632843,
#         8.99989809, 24.02524624, 16.06425326, 17.25176974, 20.77285299,
#        21.44819977, 30.51500223, 24.97491648, 19.5372341 , 19.96872256,
#        24.55222747, 15.39804616, 21.65856097, 14.93052994, 34.67698604,
#        13.12127728, 20.77225207, 13.16127538, 26.91658778, 39.78339101,
#        18.64827604, 16.84427368,  8.03517395, 29.42522446, 12.48347841,
#        37.53284601, 10.75634758, 23.53381062, 27.57811049, 35.4036338 ,
#        26.84266149, 13.81991096, 19.11829451, 30.12843581, 24.24073006,
#        24.80483304, 20.00244947, 19.71228399, 21.19366286, 28.99414939,
#        15.77360581, 15.42250913, 27.53488861, 28.28848764, 24.11568462,
#        17.94606316, 16.23781064, 31.36137204, 22.63518445, 21.78288709,
#        13.06341059, 18.5740038 , 16.61933725, 22.92811147, 18.27966252,
#        15.22335936, 16.19355373, 12.67487256, 31.04721633, 24.77391668,
#        36.20163622, 17.03657079, 28.67223416, 19.41784944, 20.29596666,
#        32.84016762, 16.29668782, 26.17014989, 19.16581668, 39.94403015,
#        14.96853252, 20.47367945, 40.6890822 ,  2.79560752, 17.32477135,
#        34.32998261, 30.35622589, 14.48020942, 18.24955942, 13.08571247,
#        21.68631306, 14.37762672, 24.59019578, 23.9321766 , 24.79930298,
#        22.37204376, 11.87744665, 38.42646651, 21.9549782 , 17.61152335,
#        25.14028726, 23.32998615, 24.21987607, 23.37044466, 21.40617942,
#        30.46337043, 22.31655701, 13.42117212, 34.02187267,  5.31368274,
#        27.02550029, 22.64524075, 21.64742097, 15.75949658, 20.51441602,
#        23.09972811, 22.00836837, 19.69072037,  9.29258119, 22.18735051,
#        31.93943592, 16.82912996, 28.11613643, 17.87235705, 18.83256648,
#        32.77445161, 21.76948557, 28.85664486, -0.98778435,  2.12453936,
#        18.54411471, 17.07540623, 35.49997752, 37.51522948, 17.32435955,
#        19.98829088, 21.99976255])

# %%
from sklearn.metrics import r2_score
round(r2_score(y_test,predictions))
# Out:
# 1

# %%
plt.scatter(y_test,predictions)

# %%
df=pd.DataFrame({'Actual':y_test,'Predictions':predictions,'Variance':ytest-predictions})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 df=pd.DataFrame({'Actual':y_test,'Predictions':predictions,'Variance':ytest-predictions})
#
# NameError: name 'ytest' is not defined
